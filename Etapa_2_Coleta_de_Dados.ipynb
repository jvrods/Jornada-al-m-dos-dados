# %% [markdown]
# ### Apresentação do Projeto
#
# Proposta para a construção de uma aplicação que realiza análise de sentimento dos candidatos à presidência.

# %% [markdown]
# Instalação das Bibliotecas

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %% [markdown]
# Importando as Bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

#Manipulação de Dados
import pandas as pd

# %%
maximo_de_tweets = 50

# %% [markdown]
# ### Lula

# %%
lista_de_tweets_lula = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
type(lista_de_tweets_lula)
# Out:
# list

# %%
dataframe_tweets_lula = pd.DataFrame(lista_de_tweets_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866989912069
# 1 2022-07-31 16:29:19+00:00  1553779853832470531
# 2 2022-07-31 16:29:18+00:00  1553779848748957696
# 3 2022-07-31 16:29:17+00:00  1553779846676987904
# 4 2022-07-31 16:29:17+00:00  1553779846324424704
#
#                                                Tweet
# 0  @UOLNoticias @LulaOficial Inacreditável esse c...
# 1  Quer o impeachment de Lula ou de Bolsonaro em ...
# 2  O Brasil está muito pior do que quando Lula as...
# 3  @HumbleRathaway @LulaOficial É pq qm deve teme...
# 4  @LulaOficial @ricardostuckert De quando é a fo...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866989912069
# 1 2022-07-31 16:29:19+00:00  1553779853832470531
# 2 2022-07-31 16:29:18+00:00  1553779848748957696
# 3 2022-07-31 16:29:17+00:00  1553779846676987904
# 4 2022-07-31 16:29:17+00:00  1553779846324424704
#
#                                                Tweet Candidato
# 0  @UOLNoticias @LulaOficial Inacreditável esse c...      Lula
# 1  Quer o impeachment de Lula ou de Bolsonaro em ...      Lula
# 2  O Brasil está muito pior do que quando Lula as...      Lula
# 3  @HumbleRathaway @LulaOficial É pq qm deve teme...      Lula
# 4  @LulaOficial @ricardostuckert De quando é a fo...      Lula

# %% [markdown]
# ### Bolsonaro

# %%
lista_de_tweets_bolsonaro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(lista_de_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866809602049
# 1 2022-07-31 16:29:22+00:00  1553779866692198401
# 2 2022-07-31 16:29:22+00:00  1553779863907098624
# 3 2022-07-31 16:29:21+00:00  1553779863408021504
# 4 2022-07-31 16:29:20+00:00  1553779857116520448
#
#                                                Tweet
# 0  gente, juro que fico incrédula com gente que v...
# 1  @joao_knorr @jairbolsonaro @JoelPeixoto15 @Lil...
# 2  @ManfroiRenato @jairbolsonaro Tá certo aumento...
# 3  Eu sou o Brasil, por isso eu apoio Bolsonaro, ...
# 4  @JosiasPontesOfc Não existe enquete quando se ...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866809602049
# 1 2022-07-31 16:29:22+00:00  1553779866692198401
# 2 2022-07-31 16:29:22+00:00  1553779863907098624
# 3 2022-07-31 16:29:21+00:00  1553779863408021504
# 4 2022-07-31 16:29:20+00:00  1553779857116520448
#
#                                                Tweet  Candidato
# 0  gente, juro que fico incrédula com gente que v...  Bolsonaro
# 1  @joao_knorr @jairbolsonaro @JoelPeixoto15 @Lil...  Bolsonaro
# 2  @ManfroiRenato @jairbolsonaro Tá certo aumento...  Bolsonaro
# 3  Eu sou o Brasil, por isso eu apoio Bolsonaro, ...  Bolsonaro
# 4  @JosiasPontesOfc Não existe enquete quando se ...  Bolsonaro

# %% [markdown]
# #### Ciro Gomes

# %%
lista_de_tweets_ciro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['ciro gomes']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_de_tweets_ciro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866130157573
# 1 2022-07-31 16:29:19+00:00  1553779851387179008
# 2 2022-07-31 16:29:18+00:00  1553779847012515843
# 3 2022-07-31 16:29:15+00:00  1553779836035932160
# 4 2022-07-31 16:29:02+00:00  1553779780146941953
#
#                                                Tweet
# 0  @FGuerreiroMEP @InternetMaluco @cirogomes @Glo...
# 1                                    @cirogomes Çei!
# 2                   @cirogomes É verdade esse bilete
# 3  @Mariana84M @cirogomes Nem pau Juvenal Ciro ou...
# 4  @RicardoAmancio8 @AndreJanonesAdv @cirogomes M...

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro Gomes'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866130157573
# 1 2022-07-31 16:29:19+00:00  1553779851387179008
# 2 2022-07-31 16:29:18+00:00  1553779847012515843
# 3 2022-07-31 16:29:15+00:00  1553779836035932160
# 4 2022-07-31 16:29:02+00:00  1553779780146941953
#
#                                                Tweet   Candidato
# 0  @FGuerreiroMEP @InternetMaluco @cirogomes @Glo...  Ciro Gomes
# 1                                    @cirogomes Çei!  Ciro Gomes
# 2                   @cirogomes É verdade esse bilete  Ciro Gomes
# 3  @Mariana84M @cirogomes Nem pau Juvenal Ciro ou...  Ciro Gomes
# 4  @RicardoAmancio8 @AndreJanonesAdv @cirogomes M...  Ciro Gomes

# %%
dataframe_final = pd.concat([dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro], axis = 0)

# %%
dataframe_final.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 16:29:22+00:00  1553779866989912069
# 1 2022-07-31 16:29:19+00:00  1553779853832470531
# 2 2022-07-31 16:29:18+00:00  1553779848748957696
# 3 2022-07-31 16:29:17+00:00  1553779846676987904
# 4 2022-07-31 16:29:17+00:00  1553779846324424704
#
#                                                Tweet Candidato
# 0  @UOLNoticias @LulaOficial Inacreditável esse c...      Lula
# 1  Quer o impeachment de Lula ou de Bolsonaro em ...      Lula
# 2  O Brasil está muito pior do que quando Lula as...      Lula
# 3  @HumbleRathaway @LulaOficial É pq qm deve teme...      Lula
# 4  @LulaOficial @ricardostuckert De quando é a fo...      Lula

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Lula', 'Bolsonaro', 'Ciro Gomes'], dtype=object)

# %%
dataframe_final.to_csv('dataframe_final_candidatos.csv', sep=',', index=False)
